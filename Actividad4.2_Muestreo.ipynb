# %% [markdown]
# # Actividad 4.2: Muestreo

# %%
import numpy as np
import pandas as pd
import scipy as sp
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
#Crear las siguientes distribuciones:
    #Binomial (n=25, p=.7)
    #Uniforme para un dado de 6 caras
    #Exponencial (teta=10)

# %%
binom=stats.binom(n=25, p=0.7)
unif=stats.randint(low=1, high=7)
expon=stats.expon(10.0)

# %%
np.random.seed(100)
binom_sample=binom.rvs(300)
binom_sample
# Out:
# array([17, 19, 18, 15, 23, 20, 17, 15, 20, 17, 15, 19, 20, 20, 19, 13, 15,
#        20, 15, 19, 18, 14, 15, 19, 20, 18, 23, 19, 16, 22, 17, 17, 20, 18,
#        21, 15, 13, 21, 15, 17, 16, 17, 17, 22, 19, 17, 16, 19, 19, 15, 13,
#        15, 18, 17, 18, 19, 20, 19, 21, 18, 18, 17, 17, 20, 14, 14, 17, 18,
#        18, 19, 19, 19, 20, 13, 13, 17, 16, 19, 20, 18, 18, 21, 17, 12, 18,
#        19, 16, 16, 19, 17, 17, 19, 20, 19, 18, 17, 19, 17, 19, 17, 16, 16,
#        17, 19, 16, 15, 17, 13, 13, 20, 22, 20, 14, 14, 19, 18, 17, 19, 18,
#        16, 18, 16, 17, 24, 18, 18, 18, 18, 18, 18, 21, 19, 14, 22, 21, 19,
#        17, 12, 12, 12, 20, 17, 17, 20, 14, 19, 10, 17, 20, 18, 20, 18, 17,
#        16, 18, 19, 17, 18, 18, 19, 19, 18, 18, 15, 16, 16, 18, 18, 17, 16,
#        20, 20, 18, 20, 13, 15, 17, 19, 20, 13, 16, 15, 18, 19, 19, 15, 18,
#        17, 16, 19, 21, 16, 13, 14, 18, 17, 16, 14, 20, 18, 18, 16, 18, 15,
# ...

# %%
np.random.seed(100)
unif_sample=unif.rvs(300)
unif_sample
# Out:
# array([1, 1, 4, 1, 3, 5, 3, 6, 3, 3, 3, 2, 1, 1, 5, 4, 5, 3, 1, 4, 2, 6,
#        3, 4, 5, 5, 2, 6, 6, 4, 5, 5, 4, 4, 4, 2, 2, 6, 4, 1, 3, 2, 2, 4,
#        3, 6, 4, 1, 2, 1, 6, 5, 3, 1, 1, 3, 6, 3, 2, 1, 6, 3, 2, 6, 5, 3,
#        1, 4, 4, 4, 6, 1, 6, 2, 5, 3, 4, 4, 5, 3, 5, 4, 2, 1, 5, 4, 5, 6,
#        3, 3, 5, 3, 6, 5, 2, 3, 3, 1, 3, 3, 4, 6, 5, 3, 5, 4, 6, 2, 1, 1,
#        6, 2, 6, 3, 5, 3, 4, 4, 2, 3, 4, 1, 2, 6, 6, 2, 6, 4, 1, 5, 3, 6,
#        5, 4, 5, 5, 3, 1, 2, 1, 5, 6, 3, 6, 5, 5, 6, 2, 1, 2, 1, 5, 3, 1,
#        6, 4, 3, 3, 4, 6, 5, 2, 4, 2, 5, 1, 1, 6, 3, 5, 3, 3, 3, 2, 3, 2,
#        6, 3, 3, 6, 1, 3, 6, 4, 5, 6, 3, 2, 3, 6, 2, 6, 2, 3, 5, 3, 4, 6,
#        5, 5, 2, 4, 1, 3, 6, 3, 6, 2, 2, 3, 6, 5, 1, 4, 4, 5, 3, 6, 1, 6,
#        1, 1, 6, 2, 4, 3, 4, 2, 1, 6, 3, 1, 1, 2, 2, 6, 3, 4, 4, 2, 6, 5,
#        6, 4, 3, 2, 5, 5, 2, 6, 5, 4, 5, 4, 6, 6, 3, 5, 4, 3, 6, 1, 3, 1,
#        1, 2, 6, 6, 5, 6, 1, 1, 4, 1, 6, 2, 5, 4, 5, 3, 6, 1, 2, 5, 1, 4,
# ...

# %%
np.random.seed(100)
expon_sample=expon.rvs(300)
expon_sample
# Out:
# array([10.78395837, 10.32624188, 10.55254662, 11.8628869 , 10.00473003,
#        10.12961805, 11.11093516, 11.7478541 , 10.14700066, 10.85588573,
#        12.21936548, 10.23471287, 10.20496997, 10.11471176, 10.2480736 ,
#        13.84547641, 11.66962936, 10.18867089, 11.69404173, 10.32030685,
#        10.56511319, 12.81390783, 11.70182395, 10.40964174, 10.19286954,
#        10.46654091, 10.00570475, 10.29092245, 11.58798228, 10.01537253,
#        10.91340335, 10.9258476 , 10.11109659, 10.48117531, 10.03715794,
#        12.21102342, 13.95915953, 10.06181369, 12.2122504 , 10.86015027,
#        11.35665668, 10.99474952, 10.87189639, 10.0206509 , 10.23575598,
#        10.78676552, 11.46583627, 10.28860947, 10.33672624, 11.91321609,
#        13.68913923, 12.16154825, 10.4455184 , 10.91344216, 10.43818813,
#        10.41580369, 10.19611342, 10.2714075 , 10.04589974, 10.70406947,
#        10.47200957, 10.89846408, 10.99409519, 10.15385109, 12.71569887,
# ...

# %%
#Para cada una de las distribuciones anteriores.
#  Generar una muestra grande (200 o más)
#  Tomar 100 muestras bootstrap de la muestra original
#  Encontrar la media, la mediana y el percentil 23 de cada boostrap y guardarlo
#  Graficar un histograma de las 100 medias, medianas y percentiles 23
#  Mostrar los 3 estadísticos de la muestra junto con sus intervalos de confianza del 95%.

# %%
def bootstrap(data,n_samples=100):
    bootstrap_medians=[] #definición de listas vacias
    bootstrap_means=[]
    bootstrap_23=[]
    
    for i in range(n_samples): #para cada muestra generada...
        bootstrap_sample=np.random.choice(data,size=len(data),replace=True)
        bootstrap_medians.append(np.median(bootstrap_sample))
        bootstrap_means.append(np.mean(bootstrap_sample))
        bootstrap_23.append(np.percentile(bootstrap_sample,23))

    fig,ax=plt.subplots(1,figsize=(15,8))
    ax.hist(bootstrap_medians,bins=25,density=True,color='black',alpha=0.4,
               label="Medianas")
    ax.hist(bootstrap_means,bins=25,density=True,color='red',alpha=0.75,
               label="Medias")
    ax.hist(bootstrap_23,bins=25,density=True,color='blue',alpha=0.55,
               label="Percentil 23")
    ax.legend()
    _=ax.set_title("Bootstrap de una muestra", fontsize=10)
    return bootstrap_medians, bootstrap_means, bootstrap_23

# %%
binom_median, binom_mean, binom_23 = bootstrap(binom_sample, n_samples=500)

# %%
unif_median, unif_mean, unif_23 = bootstrap(unif_sample, n_samples=500)

# %%
expon_median, expon_mean, expon_23 = bootstrap(expon_sample, n_samples=500)

# %%
#Media binomial
izq=np.percentile(binom_mean,2.5) #-->IC=97.5 der
der=np.percentile(binom_mean,97.5)
print("Media: {:2.2f}".format(np.mean(binom_sample)))
# Out:
# Media: 17.45

# %%
print("IC Bootstrap: [{:2.2f},{:2.2f}]".format(izq,der))
# Out:
# IC Bootstrap: [17.18,17.71]

# %% [markdown]
# #### Muestra binomial:

# %%
izq=np.percentile(binom_mean,2.5) #-->IC=97.5 der
der=np.percentile(binom_mean,97.5)
print("Media: {:2.2f}".format(np.mean(binom_sample)))
print("IC Bootstrap: [{:2.2f},{:2.2f}]".format(izq,der))

izq=np.percentile(binom_median,2.5) #-->IC=97.5 der
der=np.percentile(binom_median,97.5)
print("Mediana: {:2.2f}".format(np.median(binom_sample)))
print("IC Bootstrap: [{:2.2f},{:2.2f}]".format(izq,der))

izq=np.percentile(binom_23,2.5) #-->IC=97.5 der
der=np.percentile(binom_23,97.5)
print("Percetil 23: {:2.2f}".format(np.percentile(binom_sample,23)))
print("IC Bootstrap: [{:2.2f},{:2.2f}]".format(izq,der))
# Out:
# Media: 17.45
# IC Bootstrap: [17.18,17.71]
# Mediana: 18.00
# IC Bootstrap: [17.00,18.00]
# Percetil 23: 16.00
# IC Bootstrap: [15.00,16.00]

# %% [markdown]
# #### Muestra uniforme:

# %%
izq=np.percentile(unif_mean,2.5) #-->IC=97.5 der
der=np.percentile(unif_mean,97.5)
print("Media: {:2.2f}".format(np.mean(unif_sample)))
print("IC Bootstrap Media: [{:2.2f},{:2.2f}]".format(izq,der))

izq=np.percentile(unif_median,2.5) #-->IC=97.5 der
der=np.percentile(unif_median,97.5)
print("Mediana: {:2.2f}".format(np.median(unif_sample)))
print("IC Bootstrap Mediana: [{:2.2f},{:2.2f}]".format(izq,der))

izq=np.percentile(unif_23,2.5) #-->IC=97.5 der
der=np.percentile(unif_23,97.5)
print("Percetil 23: {:2.2f}".format(np.percentile(unif_sample,23)))
print("IC Bootstrap Percentil 23: [{:2.2f},{:2.2f}]".format(izq,der))
# Out:
# Media: 3.60
# IC Bootstrap Media: [3.39,3.81]
# Mediana: 4.00
# IC Bootstrap Mediana: [3.00,4.00]
# Percetil 23: 2.00
# IC Bootstrap Percentil 23: [2.00,2.00]

# %% [markdown]
# #### Muestra exponencial

# %%
izq=np.percentile(expon_mean,2.5) #-->IC=97.5 der
der=np.percentile(expon_mean,97.5)
print("Media: {:2.2f}".format(np.mean(expon_sample)))
print("IC Bootstrap Media: [{:2.2f},{:2.2f}]".format(izq,der))

izq=np.percentile(expon_median,2.5) #-->IC=97.5 der
der=np.percentile(expon_median,97.5)
print("Mediana: {:2.2f}".format(np.median(expon_sample)))
print("IC Bootstrap Mediana: [{:2.2f},{:2.2f}]".format(izq,der))

izq=np.percentile(expon_23,2.5) #-->IC=97.5 der
der=np.percentile(expon_23,97.5)
print("Percetil 23: {:2.2f}".format(np.percentile(expon_sample,23)))
print("IC Bootstrap Percentil 23: [{:2.2f},{:2.2f}]".format(izq,der))
# Out:
# Media: 11.06
# IC Bootstrap Media: [10.94,11.18]
# Mediana: 10.68
# IC Bootstrap Mediana: [10.57,10.80]
# Percetil 23: 10.27
# IC Bootstrap Percentil 23: [10.23,10.33]

# %%
#Bootstrap para intervalo de confianza (Ejercicio de la Empresa X)

# %%
doc=open("productivity.txt","r")

# %%
#25 personas
sample=doc.readlines()
sample
# Out:
# ['-1.910000000000000142e+01\n',
#  '-1.519999999999999929e+01\n',
#  '-1.240000000000000036e+01\n',
#  '-1.539999999999999858e+01\n',
#  '-8.699999999999999289e+00\n',
#  '-6.699999999999999289e+00\n',
#  '-5.899999999999999467e+00\n',
#  '-3.500000000000000000e+00\n',
#  '-3.099999999999999645e+00\n',
#  '-2.099999999999999645e+00\n',
#  '4.200000000000001066e+00\n',
#  '6.099999999999999645e+00\n',
#  '7.000000000000001776e+00\n',
#  '9.099999999999999645e+00\n',
#  '1.000000000000000178e+01\n',
#  '1.029999999999999893e+01\n',
#  '1.320000000000000107e+01\n',
#  '1.009999999999999964e+01\n',
#  '1.409999999999999964e+01\n',
#  '1.440000000000000036e+01\n',
#  '2.010000000000000142e+01\n',
#  '2.629999999999999716e+01\n',
#  '2.769999999999999574e+01\n',
#  '2.219999999999999574e+01\n',
#  '2.339999999999999858e+01\n']

# %%
sample_values=np.array(sample).astype(np.float)
# Out:
# C:\Users\CRAMIREZA\AppData\Local\Temp\ipykernel_21348\2899494381.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sample_values=np.array(sample).astype(np.float)

# %%
def bootstrap_ci(sample_values, stat_function=np.mean, resamples=10000, ci=95):
    statistics=np.zeros(resamples) #crear doc en ceros para poner los resamples
    for i in range(resamples):
        bootstrap= np.random.choice(sample_values, len(sample_values), replace=True)
        statistic= stat_function(bootstrap)
        statistics[i]= statistic
    lower_bound= (100-ci)/2
    return np.percentile(statistics, lower_bound), stat_function(sample_values), np.percentile(statistics,100-lower_bound),statistics

# %%
lower, estimate, upper, bootstraps= bootstrap_ci(sample_values)

# %%
lower, estimate, upper
# Out:
# (-0.30799999999999983, 5.044, 10.204099999999999)

# %%
plt.hist(bootstraps);

# %%
bootstraps
# Out:
# array([2.152, 3.944, 1.624, ..., 5.62 , 4.136, 5.212])
